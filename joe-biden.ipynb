# %%
import pandas as pd

# Correct file path
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/hashtag_joebiden.csv'

# Load the CSV file
df = pd.read_csv(file_path, lineterminator='\n')

# Display the first few rows of the dataframe
df.head()

# %%
with open('/Users/may/Documents/GitHub/DataCircle_Twitter_Project/hashtag_joebiden.csv', 'r') as file:
    print(file.readline())
# Out:
# created_at,tweet_id,tweet,likes,retweet_count,source,user_id,user_name,user_screen_name,user_description,user_join_date,user_followers_count,user_location,lat,long,city,country,continent,state,state_code,collected_at

# %%
df_cleaned = df.drop_duplicates()
df_cleaned

# %%
df.shape
rows, columns = df.shape
print(f'The DataFrame has {rows} rows and {columns} columns.')

# %%
df_cleaned = df.dropna(how='all')
df_cleaned

# %%
import re
import pandas as pd

# Function to remove URLs from text with handling for non-string values
def remove_urls(text):
    # Check if the input is a string
    if isinstance(text, str):  
        url_pattern = re.compile(r'http[s]?://\S+')
        # Remove URLs from the text
        return url_pattern.sub('', text)
    else:
        # If the input is not a string (e.g., NaN or float), return it as is
        return text

# Assume 'df' is your DataFrame and it has a 'tweet' column

# Apply the remove_urls function to each tweet in the 'tweet' column
df['tweet_cleaned'] = df['tweet'].apply(remove_urls)

# Optionally, print the original and cleaned tweets to see the result
print(df[['tweet', 'tweet_cleaned']])

# %%
print(df['tweet_cleaned'].head(10))

# %%
df.head()

# %%
import pandas as pd

# Correct file path for hashtag_donaldtrump.csv
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/hashtag_donaldtrump.csv'

# Load the CSV file
df_trump = pd.read_csv(file_path, lineterminator='\n')

# Display the first few rows of the dataframe
df_trump.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
# 3  2020-10-15 00:00:02  1.316529e+18
# 4  2020-10-15 00:00:08  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4  You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
#
#                source       user_id              user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08     El Sol Latino News  elsollatinonews
# 1    Social Mediaset   3.316176e+08                Tgcom24  MediasetTgcom24
# ...

# %%
import re
import pandas as pd

# Function to remove URLs from text with handling for non-string values
def remove_urls(text):
    # Check if the input is a string
    if isinstance(text, str):  
        url_pattern = re.compile(r'http[s]?://\S+')
        # Remove URLs from the text
        return url_pattern.sub('', text)
    else:
        # If the input is not a string (e.g., NaN or float), return it as is
        return text

# Correct file path for hashtag_donaldtrump.csv
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/hashtag_donaldtrump.csv'

# Load the CSV file
df_trump = pd.read_csv(file_path, lineterminator='\n')

# Apply the remove_urls function to each tweet in the 'tweet' column
df_trump['tweet_cleaned'] = df_trump['tweet'].apply(remove_urls)

# Optionally, print the original and cleaned tweets to see the result
print(df_trump[['tweet', 'tweet_cleaned']])
# Out:
#                                                     tweet  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...
# 1       Usa 2020, Trump contro Facebook e Twitter: cop...
# 2       #Trump: As a student I used to hear for years,...
# 3       2 hours since last tweet from #Trump! Maybe he...
# 4       You get a tie! And you get a tie! #Trump ‘s ra...
# ...                                                   ...
# 970914  @PelleX @Mikerger @spiegelbilderz_ @BertiFranz...
# 970915  JOE BIDEN WHY JOE BIDEN DID WINNED ?? TRUMP TR...
# 970916  #AfD|ler reagieren panisch bis hysterisch auf ...
# 970917  @sammelbis1998 @iheartmindy @bnorthg First, yo...
# 970918  OK just had to do it !\n#Trump #CatapultTrump ...
#
#                                             tweet_cleaned
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...
# 1       Usa 2020, Trump contro Facebook e Twitter: cop...
# 2       #Trump: As a student I used to hear for years,...
# ...
