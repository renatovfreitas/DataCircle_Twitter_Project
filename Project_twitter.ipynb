# %%
import pandas as pd

# %%
df_biden = pd.read_csv(r"E:\Redi School\Data Circle 2024\Project\hashtag_joebiden.csv", lineterminator='\n')

# %%
# Load the Trump dataset
df_trump = pd.read_csv(r"E:\Redi School\Data Circle 2024\Project\hashtag_donaldtrump.csv", lineterminator='\n')

# %% [markdown]
# 2. Explore the Data

# %%
print(df_biden.columns)
# Out:
# Index(['created_at', 'tweet_id', 'tweet', 'likes', 'retweet_count', 'source',
#        'user_id', 'user_name', 'user_screen_name', 'user_description',
#        'user_join_date', 'user_followers_count', 'user_location', 'lat',
#        'long', 'city', 'country', 'continent', 'state', 'state_code',
#        'collected_at'],
#       dtype='object')

# %%
print(df_trump.columns)
# Out:
# Index(['created_at', 'tweet_id', 'tweet', 'likes', 'retweet_count', 'source',
#        'user_id', 'user_name', 'user_screen_name', 'user_description',
#        'user_join_date', 'user_followers_count', 'user_location', 'lat',
#        'long', 'city', 'country', 'continent', 'state', 'state_code',
#        'collected_at'],
#       dtype='object')

# %%
# Check for data types and null values
print(df_biden.info())
print(df_trump.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776886 entries, 0 to 776885
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            776886 non-null  object
#  1   tweet_id              776886 non-null  float64
#  2   tweet                 776886 non-null  object
#  3   likes                 776886 non-null  float64
#  4   retweet_count         776886 non-null  float64
#  5   source                776173 non-null  object
#  6   user_id               776886 non-null  float64
#  7   user_name             776868 non-null  object
#  8   user_screen_name      776886 non-null  object
#  9   user_description      694880 non-null  object
#  10  user_join_date        776886 non-null  object
#  11  user_followers_count  776886 non-null  float64
#  12  user_location         543095 non-null  object
#  13  lat                   355293 non-null  float64
# ...

# %%
print(df_trump.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970903 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869653 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675966 non-null  object
#  13  lat                   445719 non-null  float64
# ...

# %%
df_biden['candidate'] = 'Biden'
df_trump['candidate'] = 'Trump'

# %%
print(df_biden.columns)
# Out:
# Index(['created_at', 'tweet_id', 'tweet', 'likes', 'retweet_count', 'source',
#        'user_id', 'user_name', 'user_screen_name', 'user_description',
#        'user_join_date', 'user_followers_count', 'user_location', 'lat',
#        'long', 'city', 'country', 'continent', 'state', 'state_code',
#        'collected_at', 'candidate'],
#       dtype='object')

# %%
df_combined = pd.concat([df_biden, df_trump], ignore_index=True)

# %%
print(df_combined.columns)
# Out:
# Index(['created_at', 'tweet_id', 'tweet', 'likes', 'retweet_count', 'source',
#        'user_id', 'user_name', 'user_screen_name', 'user_description',
#        'user_join_date', 'user_followers_count', 'user_location', 'lat',
#        'long', 'city', 'country', 'continent', 'state', 'state_code',
#        'collected_at', 'candidate'],
#       dtype='object')

# %%
print(df_combined.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747805 entries, 0 to 1747804
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   created_at            object
#  1   tweet_id              float64
#  2   tweet                 object
#  3   likes                 float64
#  4   retweet_count         float64
#  5   source                object
#  6   user_id               float64
#  7   user_name             object
#  8   user_screen_name      object
#  9   user_description      object
#  10  user_join_date        object
#  11  user_followers_count  float64
#  12  user_location         object
#  13  lat                   float64
#  14  long                  float64
#  15  city                  object
#  16  country               object
#  17  continent             object
#  18  state                 object
#  19  state_code            object
#  20  collected_at          object
#  21  candidate             object
# ...

# %%
print(df_trump.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970903 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869653 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675966 non-null  object
#  13  lat                   445719 non-null  float64
# ...

# %% [markdown]
# # Step 1: Remove Duplicates
# Objective:
# Ensure each tweet in the dataset is unique.

# %%
# Check for duplicates based on 'tweet_id' or 'tweet' content
duplicate_tweet_ids = df_combined.duplicated(subset=['tweet_id'], keep=False)
duplicate_tweets = df_combined.duplicated(subset=['tweet'], keep=False)

# %%
duplicate_tweet_ids_trump =df_trump.duplicated(subset=['tweet_id'], keep=False)

print(f"Duplicate tweet IDs trump: {duplicate_tweet_ids_trump.sum()}")

duplicate_tweets_trump = df_trump.duplicated(subset=['tweet'], keep=False)

print(f"Duplicate tweets trump: {duplicate_tweets_trump.sum()}")
# Out:
# Duplicate tweet IDs trump: 2684
# Duplicate tweets trump: 18431

# %%
duplicate_tweet_ids_biden =df_biden.duplicated(subset=['tweet_id'], keep=False)

print(f"Duplicate tweet IDs biden: {duplicate_tweet_ids_biden.sum()}")

duplicate_tweets_biden = df_biden.duplicated(subset=['tweet'], keep=False)

print(f"Duplicate tweets biden: {duplicate_tweets_biden.sum()}")
# Out:
# Duplicate tweet IDs biden: 3708
# Duplicate tweets biden: 13637

# %%
# Print how many duplicate tweets are found
print(f"Duplicate tweet IDs: {duplicate_tweet_ids.sum()}")
print(f"Duplicate tweets: {duplicate_tweets.sum()}")
# Out:
# Duplicate tweet IDs: 448582
# Duplicate tweets: 468067

# %% [markdown]
# # Step 2: Handle Missing Data
# Objective:
# Deal with incomplete or missing values.

# %%
# Check for missing values in key columns
missing_values = df_combined.isnull().sum()
print("Missing values before handling:\n", missing_values)
# Out:
# Missing values before handling:
#  created_at                    0
# tweet_id                      0
# tweet                         0
# likes                         0
# retweet_count                 0
# source                     1589
# user_id                       0
# user_name                    34
# user_screen_name              0
# user_description         183272
# user_join_date                0
# user_followers_count          0
# user_location            528744
# lat                      946793
# long                     946793
# city                    1333746
# country                  951278
# continent                951243
# state                   1166990
# state_code              1202771
# collected_at                  0
# candidate                     0
# dtype: int64

# %% [markdown]
# Ensure Data Consistency
#
#     Standardizing date/time formats
#     Ensuring consistent text formatting (e.g., lowercasing)
#     Cleaning up usernames and hashtags (removing extra spaces or symbols)

# %% [markdown]
# # 1. Textual Data:
# These columns contain free-form text, such as user descriptions or tweet content.
#
# tweet
#
# user_description
#
# source
#
# user_name
#
# user_screen_name
#
# # 2. Numerical Data:
# These columns are quantitative and can be used for numerical analysis.
#
# likes (converted to numeric)
#
# retweet_count
#
# user_followers_count
#
# lat (converted to numeric)
#
# long (converted to numeric)
#
# # 3. Categorical Data:
# These columns represent categories or classifications (nominal or ordinal data).
#
# candidate (Trump/Biden)
#
# city (standardized)
#
# country (standardized)
#
# continent
#
# state (standardized)
#
# state_code (standardized)
#
# # 4. Temporal Data:
# These columns represent dates and times.
#
# created_at
#
# user_join_date
#
# collected_at
#
# # 5. Geographical Data:
# These columns represent geographic information, including city, country, state, latitude, and longitude.
#
# city
#
# country
#
# state
#
# state_code
#
# lat
#
# long

# %% [markdown]
# # Standardize Date/Time (created_at)
# This ensures that all dates are in a consistent format.

# %%
df_combined['created_at'] = pd.to_datetime(df_combined['created_at'], errors='coerce')

# %%
# Convert the date columns to datetime format
df_combined['created_at'] = pd.to_datetime(df_combined['created_at'], errors='coerce')
df_combined['user_join_date'] = pd.to_datetime(df_combined['user_join_date'], errors='coerce')
df_combined['collected_at'] = pd.to_datetime(df_combined['collected_at'], errors='coerce')

# %%
# Checking for any null or inconsistent values after conversion
print(df_combined[['created_at', 'user_join_date', 'collected_at']].isnull().sum())
# Out:
# created_at        0
# user_join_date    0
# collected_at      0
# dtype: int64

# %%
# List of temporal columns
temporal_columns = ['created_at', 'user_join_date', 'collected_at']

# Find unique values for each temporal column
for column in temporal_columns:
    unique_values = df_combined[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("\n")
# Out:
# Unique values in column 'created_at':
# ['2020-10-15T00:00:01.000000000' '2020-10-15T00:00:18.000000000'
#  '2020-10-15T00:00:20.000000000' ... '2020-11-08T23:59:53.000000000'
#  '2020-11-08T23:59:54.000000000' '2020-11-08T23:59:55.000000000']
#
#
# Unique values in column 'user_join_date':
# ['2011-08-23T15:33:45.000000000' '2012-09-08T01:03:57.000000000'
#  '2015-08-30T19:38:21.000000000' ... '2013-05-10T00:21:43.000000000'
#  '2015-05-10T19:56:37.000000000' '2018-04-18T14:21:49.000000000']
#
#
# Unique values in column 'collected_at':
# ['2020-10-21T00:00:00.000000000' '2020-10-21T00:00:00.517827283'
#  '2020-10-21T00:00:01.035654566' ... '2020-11-09T17:47:55.975868000'
#  '2020-11-09T17:47:56.012674000' '2020-11-09T17:47:55.807500000']

# %% [markdown]
# # Convert 'likes', 'user_followers_count', 'lat', 'long' to numeric types

# %%
# Convert 'likes', 'user_followers_count', 'lat', 'long' to numeric types
df_combined['likes'] = pd.to_numeric(df_combined['likes'], errors='coerce')
df_combined['user_followers_count'] = pd.to_numeric(df_combined['user_followers_count'], errors='coerce')
df_combined['lat'] = pd.to_numeric(df_combined['lat'], errors='coerce')
df_combined['long'] = pd.to_numeric(df_combined['long'], errors='coerce')

# %%
# Check for any null values after conversion
print(df_combined[['likes', 'user_followers_count', 'lat', 'long']].isnull().sum())
# Out:
# likes                        0
# user_followers_count         0
# lat                     946793
# long                    946793
# dtype: int64

# %% [markdown]
# # Standardize categorical columns
# Text columns like tweet, user_name, user_screen_name, etc., are converted to lowercase and trimmed of any extra spaces.

# %%
# Standardize categorical columns
df_combined['source'] = df_combined['source'].str.lower().str.strip()
df_combined['city'] = df_combined['city'].str.lower().str.strip()
df_combined['country'] = df_combined['country'].str.lower().str.strip()
df_combined['state'] = df_combined['state'].str.lower().str.strip()
df_combined['state_code'] = df_combined['state_code'].str.upper().str.strip()

# %%
text_columns = ['tweet', 'user_name', 'user_screen_name', 'user_description', 'user_location', 'source']
for col in text_columns:
    df_combined[col] = df_combined[col].str.lower().str.strip()

# %%
# Check for any null values after conversion
print(df_combined[text_columns].isnull().sum())
# Out:
# tweet                    0
# user_name               34
# user_screen_name         0
# user_description    183272
# user_location       528744
# source                1589
# dtype: int64

# %%
print(df_combined.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747805 entries, 0 to 1747804
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   created_at            datetime64[ns]
#  1   tweet_id              float64
#  2   tweet                 object
#  3   likes                 float64
#  4   retweet_count         float64
#  5   source                object
#  6   user_id               float64
#  7   user_name             object
#  8   user_screen_name      object
#  9   user_description      object
#  10  user_join_date        object
#  11  user_followers_count  float64
#  12  user_location         object
#  13  lat                   float64
#  14  long                  float64
#  15  city                  object
#  16  country               object
#  17  continent             object
#  18  state                 object
#  19  state_code            object
#  20  collected_at          object
#  21  candidate             object
# ...

# %%
pip install matplotlib seaborn
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df_combined['country'].unique())
# Out:
# ['united states of america' nan 'united states' 'united kingdom' 'poland'
#  'china' 'spain' 'egypt' 'mexico' 'russia' 'georgia' 'canada' 'jersey'
#  'australia' 'mongolia' 'greece' 'germany' 'netherlands' 'new zealand'
#  'the netherlands' 'vietnam' 'switzerland' 'costa rica' 'singapore'
#  'austria' 'malaysia' 'panama' 'japan' 'south korea' 'cuba' 'colombia'
#  'venezuela' 'brazil' 'turkey' 'india' 'argentina' 'indonesia' 'sweden'
#  'slovenia' 'papua new guinea' 'albania' 'peru' 'united arab emirates'
#  'iran' 'ecuador' 'saudi arabia' 'italy' 'afghanistan' 'france' 'iraq'
#  'taiwan' 'tunisia' 'philippines' 'bangladesh' 'chile' 'guyana' 'finland'
#  'cambodia' 'pakistan' 'slovakia' 'luxembourg' 'portugal' 'south africa'
#  'nigeria' 'bosnia and herzegovina' 'belgium' 'denmark' 'norway'
#  'czech republic' 'sierra leone' 'uganda' 'ireland' 'lebanon' 'hungary'
#  'azerbaijan' 'kenya' 'hong kong' 'cyprus' 'djibouti' 'fiji' 'bahrain'
# ...

# %%
country_counts = df_combined['country'].value_counts()
print(country_counts)
# Out:
# united states of america    332495
# united states                61905
# united kingdom               58051
# india                        40091
# germany                      35379
#                              ...
# samoa                            2
# saint lucia                      1
# east timor                       1
# lesotho                          1
# northern mariana islands         1
# Name: country, Length: 189, dtype: int64

# %%
print(df_combined[df_combined['country'].isnull()])
# Out:
#                  created_at      tweet_id  \
# 1       2020-10-15 00:00:18  1.316529e+18
# 3       2020-10-15 00:00:21  1.316529e+18
# 5       2020-10-15 00:00:23  1.316529e+18
# 7       2020-10-15 00:00:31  1.316529e+18
# 8       2020-10-15 00:00:36  1.316529e+18
# ...                     ...           ...
# 1747800 2020-11-08 23:59:43  1.325589e+18
# 1747801 2020-11-08 23:59:48  1.325589e+18
# 1747802 2020-11-08 23:59:53  1.325589e+18
# 1747803 2020-11-08 23:59:54  1.325589e+18
# 1747804 2020-11-08 23:59:55  1.325589e+18
#
#                                                      tweet  likes  \
# 1        #hunterbiden #hunterbidenemails #joebiden #joe...    0.0
# 3        @chrislongview watching and setting dvr. let’s...    0.0
# 5        "is this wrong??!!" cory booker's brilliant fi...    0.0
# 7        ►► tell politicians to stick it with this free...    0.0
# 8                           #biden https://t.co/qms0pmuev5    0.0
# ...

# %%
# Step 1: Create a mapping dictionary
country_mapping = {
    'united states of america': 'United States',
    'united states': 'United States',
    'the netherlands': 'Netherlands',
    'south korea': 'South Korea',
    # more mappings as needed
}

# %%
#Standardize country names using the mapping
df_combined['country'] = df_combined['country'].replace(country_mapping)

# %%
print(df_combined['country'].unique())
# Out:
# ['United States' nan 'united kingdom' 'poland' 'china' 'spain' 'egypt'
#  'mexico' 'russia' 'georgia' 'canada' 'jersey' 'australia' 'mongolia'
#  'greece' 'germany' 'netherlands' 'new zealand' 'Netherlands' 'vietnam'
#  'switzerland' 'costa rica' 'singapore' 'austria' 'malaysia' 'panama'
#  'japan' 'South Korea' 'cuba' 'colombia' 'venezuela' 'brazil' 'turkey'
#  'india' 'argentina' 'indonesia' 'sweden' 'slovenia' 'papua new guinea'
#  'albania' 'peru' 'united arab emirates' 'iran' 'ecuador' 'saudi arabia'
#  'italy' 'afghanistan' 'france' 'iraq' 'taiwan' 'tunisia' 'philippines'
#  'bangladesh' 'chile' 'guyana' 'finland' 'cambodia' 'pakistan' 'slovakia'
#  'luxembourg' 'portugal' 'south africa' 'nigeria' 'bosnia and herzegovina'
#  'belgium' 'denmark' 'norway' 'czech republic' 'sierra leone' 'uganda'
#  'ireland' 'lebanon' 'hungary' 'azerbaijan' 'kenya' 'hong kong' 'cyprus'
#  'djibouti' 'fiji' 'bahrain' 'israel' 'estonia' 'cameroon' 'liberia'
# ...

# %%
country_counts = df_combined['country'].value_counts()
print(country_counts)
# Out:
# United States               394400
# united kingdom               58051
# india                        40091
# germany                      35379
# france                       35299
#                              ...
# samoa                            2
# saint lucia                      1
# east timor                       1
# lesotho                          1
# northern mariana islands         1
# Name: country, Length: 188, dtype: int64

# %%
# Plot the top 10 countries
plt.figure(figsize=(12, 6))
country_counts.head(10).plot(kind='bar', color='lightblue')
plt.title('Top 10 Countries with Most Tweets (Standardized)')
plt.xlabel('Country')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Which Country Has the Most Tweets for Each Candidate?

# %%
# Group by country and candidate to count the tweets
country_tweet_counts = df_combined.groupby(['country', 'candidate']).size().reset_index(name='tweet_count')

# Check the contents of country_tweet_counts
print(country_tweet_counts)
# Out:
#            country candidate  tweet_count
# 0      Netherlands     Biden         3981
# 1      Netherlands     Trump         5606
# 2      South Korea     Biden          160
# 3      South Korea     Trump          214
# 4    United States     Biden       181137
# ..             ...       ...          ...
# 363          yemen     Trump           93
# 364         zambia     Biden           33
# 365         zambia     Trump           38
# 366       zimbabwe     Biden           59
# 367       zimbabwe     Trump           60
#
# [368 rows x 3 columns]

# %% [markdown]
# # Top 5 Countries with Most Tweets for Each Candidate

# %%
# Group by country and candidate to count the tweets
country_tweet_counts = df_combined.groupby(['country', 'candidate']).size().reset_index(name='tweet_count')

# Sort values to get top countries
sorted_counts = country_tweet_counts.sort_values(by=['candidate', 'tweet_count'], ascending=[True, False])

# %%
# Get the top 5 countries for each candidate
top_5_countries_per_candidate = sorted_counts.groupby('candidate').head(5).reset_index(drop=True)

# %%
# Display the top 5 countries
print(top_5_countries_per_candidate)
# Out:
#           country candidate  tweet_count
# 0   United States     Biden       181137
# 1  united kingdom     Biden        23308
# 2           india     Biden        21532
# 3          france     Biden        14610
# 4         germany     Biden        12761
# 5   United States     Trump       213263
# 6  united kingdom     Trump        34743
# 7         germany     Trump        22618
# 8          france     Trump        20689
# 9           india     Trump        18559

# %%
# Plotting
plt.figure(figsize=(10, 5))
sns.barplot(x='tweet_count', y='country', hue='candidate', data=top_5_countries_per_candidate, palette='Set2')
plt.title('Top 5 Countries with Most Tweets for Each Candidate')
plt.xlabel('Number of Tweets')
plt.ylabel('Country')
plt.legend(title='Candidate')
plt.show()

# %% [markdown]
# # What Time Do Users Tweet the Most?

# %%
df_combined['tweet_hour'] = df_combined['created_at'].dt.hour
# Count the number of tweets for each hour and candidate
hourly_tweet_counts = df_combined.groupby(['tweet_hour', 'candidate']).size().reset_index(name='tweet_count')

# %%
# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(data=hourly_tweet_counts, x='tweet_hour', y='tweet_count', hue='candidate', marker='o')
plt.title('Number of Tweets by Hour (24-hour Format)')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Tweets')
plt.xticks(range(0, 24))  # Show all hours in the x-axis
plt.grid(True)
plt.legend(title='Candidate')
plt.show()

# %% [markdown]
# # cities in the U.S. with the most tweets for each candidate (Biden and Trump)

# %%
# Fill NaN values in the 'country' column with an empty string
df_combined['country'] = df_combined['country'].fillna('')

# Filter the DataFrame for tweets from the United States
df_us = df_combined[df_combined['country'].str.lower().str.contains('united states')]

# %%
# Count the number of tweets for each city and candidate
city_tweet_counts = df_us.groupby(['city', 'candidate']).size().reset_index(name='tweet_count')

# Get the top 10 cities for each candidate
top_cities_per_candidate = (
    city_tweet_counts
    .sort_values(['candidate', 'tweet_count'], ascending=[True, False])
    .groupby('candidate')
    .head(10)  # Take top 10 for each candidate
)

# Reset the index for better plotting
top_cities_per_candidate.reset_index(drop=True, inplace=True)

# %%
# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x='tweet_count', y='city', hue='candidate', data=top_cities_per_candidate, palette='Set2')
plt.title('Top 10 Cities with Most Tweets for Each Candidate (U.S. Only)')
plt.xlabel('Number of Tweets')
plt.ylabel('City')
plt.legend(title='Candidate')
plt.show()

# %% [markdown]
# # Handling outliers

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set the plot style for better visuals
sns.set(style="whitegrid")

# Create a figure with 2 subplots (one for 'likes' and one for 'retweet_count')
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Box plot for 'likes' column
sns.boxplot(data=df_combined, x='likes', ax=axs[0], color='skyblue')
axs[0].set_title('Box Plot for Likes')
axs[0].set_xlabel('Likes')

# Box plot for 'retweet_count' column
sns.boxplot(data=df_combined, x='retweet_count', ax=axs[1], color='lightgreen')
axs[1].set_title('Box Plot for Retweet Count')
axs[1].set_xlabel('Retweet Count')

# Display the plots
plt.tight_layout()
plt.show()
