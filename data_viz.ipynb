# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.options.display.float_format = '{:.0f}'.format

def load_data():
    return pd.read_csv(r'/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv', lineterminator='\n')

df_combined = load_data()
df_combined.head()
# Out:
#             created_at             tweet_id  likes  retweet_count  \
# 0  2020-10-15 00:00:02  1316529228091846912      2              1
# 1  2020-10-15 00:00:02  1316529227471237120      0              0
# 2  2020-10-15 00:00:08  1316529252301451264      4              3
# 3  2020-10-15 00:00:17  1316529291052675072      2              0
# 4  2020-10-15 00:00:17  1316529289949569024      0              0
#
#                 source             user_id       user_join_date  \
# 0      twitter web app             8436472  2007-08-26 05:56:11
# 1        trumpytweeter  828355589206056960  2017-02-05 21:32:17
# 2   twitter for iphone            47413798  2009-06-15 19:05:35
# 3  twitter for android          1138416104  2013-02-01 01:37:38
# 4   twitter for iphone  767401841030209536  2016-08-21 16:43:51
#
#    user_followers_count      user_location        city        country  \
# 0                  1185           portland    portland  united states
# ...

# %% [markdown]
# Renaming the column "tweet_cleaned"

# %%
df_combined.columns = df_combined.columns.str.replace('\r', '', regex=True)
df_combined.head()
# Out:
#             created_at             tweet_id  likes  retweet_count  \
# 0  2020-10-15 00:00:02  1316529228091846912      2              1
# 1  2020-10-15 00:00:02  1316529227471237120      0              0
# 2  2020-10-15 00:00:08  1316529252301451264      4              3
# 3  2020-10-15 00:00:17  1316529291052675072      2              0
# 4  2020-10-15 00:00:17  1316529289949569024      0              0
#
#                 source             user_id       user_join_date  \
# 0      twitter web app             8436472  2007-08-26 05:56:11
# 1        trumpytweeter  828355589206056960  2017-02-05 21:32:17
# 2   twitter for iphone            47413798  2009-06-15 19:05:35
# 3  twitter for android          1138416104  2013-02-01 01:37:38
# 4   twitter for iphone  767401841030209536  2016-08-21 16:43:51
#
#    user_followers_count      user_location        city        country  \
# 0                  1185           portland    portland  united states
# ...

# %% [markdown]
# # Filter for tweets from cities in the United States

# %%
# Remove rows with 'unknown' in the country and city columns, also checking for NaN
df_combined = df_combined[
    (df_combined['country'].str.strip().str.lower() != 'unknown') & 
    (df_combined['country'].notna()) &  # Ensure country is not NaN
    (df_combined['city'].str.strip().str.lower() != 'unknown') & 
    (df_combined['city'].notna())  # Ensure city is not NaN
]

# Filter for tweets from cities in the United States
us_tweets = df_combined[df_combined['country'].str.strip().str.lower() == 'united states']

# Group by city and count tweets in each city
tweets_count_by_city = us_tweets.groupby('city')['tweet_cleaned'].count().reset_index()

# Rename columns for clarity
tweets_count_by_city.columns = ['City', 'Number of Tweets']

# Sort by Number of Tweets in descending order and get the top 5 cities
top_5_cities = tweets_count_by_city.sort_values(by="Number of Tweets", ascending=False).head(5)

# Print the top 5 cities with maximum tweets
print("Top 5 Cities by Number of Tweets:")
print(top_5_cities)

# Print the first five rows of the tweets_count_by_city for additional context
print("\nFirst five rows of tweets count by city (unsorted):")
print(tweets_count_by_city.head(5))
# Out:
# Top 5 Cities by Number of Tweets:
#             City  Number of Tweets
# 497       unkown            157902
# 330     new york             27378
# 273  los angeles             12578
# 513   washington             10949
# 88       chicago              6118
#
# First five rows of tweets count by city (unsorted):
#                 City  Number of Tweets
# 0            abilene                 8
# 1  abington township                 2
# 2               aiea                 1
# 3              akron               153
# 4             albany               122

# %% [markdown]
# # Sort by tweet count and select the top 5 cities

# %%
top_5_cities = tweets_count_by_city.sort_values(by="Number of Tweets", ascending=False).head(5)

# Display in Streamlit
st.write("Top 5 Cities by Number of Tweets:", top_5_cities)
# Out:
# 2024-10-26 14:50:36.130 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 14:50:36.258
# ...
#   command:
#
#     streamlit run /Users/may/Library/Python/3.12/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-10-26 14:50:36.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 14:50:36.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 14:50:36.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 14:50:36.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 14:50:36.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip install geopy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas geopy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
pip install pandas plotly
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# Load dataset
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'

if os.path.exists(file_path):
    df_combined = pd.read_csv(file_path, lineterminator='\n')

    # Filter for tweets from U.S. cities
    us_tweets = df_combined[df_combined['country'].str.strip().str.lower() == 'united states']

    if not us_tweets.empty:
        # Count tweets by city
        tweets_count_by_city = us_tweets.groupby('city').size().reset_index(name='Tweet Count')
        print(tweets_count_by_city)
    else:
        print("No tweets found from the United States.")
else:
    print("File not found.")
# Out:
#                   city  Tweet Count
# 0              abilene            8
# 1    abington township            2
# 2                 aiea            1
# 3                akron          153
# 4               albany          122
# ..                 ...          ...
# 528             yakima            8
# 529            yonkers           92
# 530               york            7
# 531         youngstown          114
# 532               yuma           26
#
# [533 rows x 2 columns]

# %%
pip install pandas plotly
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
print(df_combined.columns)  # Print the column names
# Out:
# Index(['created_at', 'tweet_id', 'likes', 'retweet_count', 'source', 'user_id',
#        'user_join_date', 'user_followers_count', 'user_location', 'city',
#        'country', 'state', 'candidate', 'tweet_cleaned\r'],
#       dtype='object')

# %%
us_tweets = us_tweets[us_tweets['city'].str.strip().str.lower() != 'unknown']

# %%
import pandas as pd
import plotly.express as px
import os
import streamlit as st

# Title of the app
st.title("Twitter Analysis: Top US Cities by Tweet Count")

# Specify the path to your CSV file
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'

# Check if the file exists
if os.path.exists(file_path):
    # Load the dataset
    df_combined = pd.read_csv(file_path, lineterminator='\n')

    # Filter for tweets from U.S. cities
    us_tweets = df_combined[df_combined['country'].str.strip().str.lower() == 'united states']

    # Check if there are tweets from the US
    if not us_tweets.empty:
        # Drop entries with 'unknown' in the 'city' column
        us_tweets = us_tweets[us_tweets['city'].str.strip().str.lower() != 'unknown']

        # If there are still tweets left after filtering, proceed
        if not us_tweets.empty:
            # Count tweets by city
            tweets_count_by_city = us_tweets.groupby('city').size().reset_index(name='Tweet Count')
            
            # Get the top 5 cities with the maximum tweets
            top_5_cities = tweets_count_by_city.nlargest(5, 'Tweet Count')

            # Display the top cities
            st.write("Top US Cities by Tweet Count (excluding 'unknown'):")
            st.dataframe(top_5_cities)

            # Create a bar chart
            fig = px.bar(top_5_cities,
                         x='city',
                         y='Tweet Count',
                         title='Top 5 US Cities by Number of Tweets',
                         labels={'Tweet Count': 'Number of Tweets', 'city': 'City'},
                         color='Tweet Count',
                         color_continuous_scale=px.colors.sequential.Viridis)

            # Show the bar chart
            st.plotly_chart(fig)
        else:
            st.write("No valid city data available after filtering out 'unknown' cities.")
    else:
        st.write("No tweets found from the United States.")
else:
    st.write("File not found.")
# Out:
# 2024-10-26 15:04:46.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:46.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:52.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:52.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:52.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:52.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-26 15:04:52.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# # Top 5 cities with the maximum tweets

# %%
import pandas as pd
import plotly.express as px
import os
import streamlit as st

# Title of the app
st.title("Twitter Analysis: Top US Cities by Tweet Count")

# Specify the path to your CSV file
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'

# Check if the file exists
if os.path.exists(file_path):
    # Load the dataset
    df_combined = pd.read_csv(file_path, lineterminator='\n')

    # Filter for tweets from U.S. cities
    us_tweets = df_combined[df_combined['country'].str.strip().str.lower() == 'united states']

    # Check if there are tweets from the US
    if not us_tweets.empty:
        # Define a list of incorrect city names to exclude
        incorrect_city_names = ['unknown', 'unkown', 'unknwn', 'unlown', 'unknownn']

        # Drop entries with incorrect city names in the 'city' column
        us_tweets = us_tweets[
            ~us_tweets['city'].str.strip().str.lower().isin(incorrect_city_names)
        ]

        # If there are still tweets left after filtering, proceed
        if not us_tweets.empty:
            # Count tweets by city
            tweets_count_by_city = us_tweets.groupby('city').size().reset_index(name='Tweet Count')
            
            # Get the top 5 cities with the maximum tweets
            top_5_cities = tweets_count_by_city.nlargest(5, 'Tweet Count')

            # Display the top cities
            st.write("Top US Cities by Tweet Count (excluding incorrect city names):")
            st.dataframe(top_5_cities)

            # Create a bar chart
            fig = px.bar(top_5_cities,
                         x='city',
                         y='Tweet Count',
                         title='Top 5 US Cities by Number of Tweets',
                         labels={'Tweet Count': 'Number of Tweets', 'city': 'City'},
                         color='Tweet Count',
                         color_continuous_scale=px.colors.sequential.Viridis)

            # Show the bar chart
            st.plotly_chart(fig)
        else:
            st.write("No valid city data available after filtering out incorrect city names.")
    else:
        st.write("No tweets found from the United States.")
else:
    st.write("File not found.")

# %%
import pandas as pd
import os
import re  # For regex to extract hashtags

# Specify the path to your CSV file
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'

# Check if the file exists
if os.path.exists(file_path):
    # Load the dataset
    df_combined = pd.read_csv(file_path, lineterminator='\n')

    # Display the columns for debugging
    print("Columns in DataFrame:", df_combined.columns)

    # Filter for tweets from New York
    new_york_tweets = df_combined[df_combined['city'].str.strip().str.lower() == 'new york']

    # Check if there are tweets from New York
    if not new_york_tweets.empty:
        # Extract hashtags from the 'tweet_cleaned\r' column
        hashtags = []

        # Function to extract hashtags from a tweet
        def extract_hashtags(tweet):
            return re.findall(r'#\w+', tweet)

        # Iterate through the tweets and extract hashtags
        for tweet in new_york_tweets['tweet_cleaned\r']:
            hashtags.extend(extract_hashtags(tweet))

        # Get unique hashtags
        unique_hashtags = set(hashtags)

        # Display the unique hashtags
        print("Unique Hashtags from Tweets in New York:")
        if unique_hashtags:
            for hashtag in unique_hashtags:
                print(hashtag)
        else:
            print("No hashtags found in tweets from New York.")
    else:
        print("No tweets found from New York.")
else:
    print("File not found.")
# Out:
# Columns in DataFrame: Index(['created_at', 'tweet_id', 'likes', 'retweet_count', 'source', 'user_id',
#        'user_join_date', 'user_followers_count', 'user_location', 'city',
#        'country', 'state', 'candidate', 'tweet_cleaned\r'],
#       dtype='object')
# Unique Hashtags from Tweets in New York:
# #fl
# #cashlesssociety
# #explore
# #woman
# #bidenvstrump
# #trumpterroism
# #vaccine
# #ps5
# #trumpmary
# #youmad
# #nra
# #nursinghomes
# #silentmajoritynomore
# #saturdayvibes
# #ada
# #magaisfear
# #flush
# #rescuedogs
# #kimberlydavis
# #oakland
# #billiondollar
# #joebideniscorrupt
# #fakefollowers
# #democracyhasanotherchance
# #californiafire
# #congratspresidentelectbiden
# #fairelection
# #deliman
# #bidenethics
# #synagogue
# #trumphasnoplan
# #africanamerican
# #toddlertrump
# #publicenemy
# #profit
# #crookedbiden
# #closetqueen
# #dontraisejackstaxes
# #nicklaus
# #spygate
# #reckless
# #riggedelection
# #factchecker
# #starwars
# #billieeilish
# #campaignbuttons
# ...
