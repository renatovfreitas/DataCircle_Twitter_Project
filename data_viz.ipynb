# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib plotly
# Out:
# ...
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/e5/ae/580600f441f6fc05218bd6c9d5794f4aef072a7d9093b291f1c50a9db8bc/plotly-5.24.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 12.5 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/ef/e1/f9c479f9dbe0bb702ea5ca6608f10e91a708b438f7fb4572a2642718c6e3/streamlit-1.39.0-py2.py3-none-any.whl.metadata
#   Using cached streamlit-1.39.0-py2.py3-none-any.whl.metadata (8.5 kB)
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/9b/52/4a86a4fa1cc2aae79137cc9510b7080c3e5aede2310d14fae5486feec7f7/altair-5.4.1-py3-none-any.whl.metadata
#   Using cached altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/bb/2a/10164ed1f31196a2f7f3799368a821765c62851ead0e630ab52b8e14b4d0/blinker-1.8.2-py3-none-any.whl.metadata
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# ...

# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.options.display.float_format = '{:.0f}'.format

# Load dataset function
def load_data():
    return pd.read_csv(r'/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv', lineterminator='\n')

# Load data
df_combined = load_data()

# Clean column names (removing '\r')
df_combined.columns = df_combined.columns.str.replace('\r', '')

# Title of the dashboard
st.title("Twitter Election Data Dashboard")

# ===========================
# PART 1: Distribution of Likes
# ===========================
st.header("Distribution of Likes")

# Simple plot for 'Likes'
plt.figure(figsize=(10, 6))
sns.histplot(df_combined['likes'], bins=30, kde=True)
plt.title('Distribution of Likes', fontsize=16)
plt.xlabel('Number of Likes', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Display the Seaborn plot
st.pyplot()

# %%
# PART 2: Geospatial Distribution of Tweets
# ===========================
# Drop missing latitude and longitude values for geo plot
geo_data = df_combined.dropna(subset=['latitude', 'longitude'])

# Visualization: Geographic Heatmap of Tweets
st.header("Geospatial Distribution of Tweets by Candidate")
fig_geo = px.scatter_geo(geo_data, lat='latitude', lon='longitude',
                         hover_name='candidate', color='candidate',
                         title="Tweet Locations by Candidate",
                         labels={'latitude': 'Latitude', 'longitude': 'Longitude'})
st.plotly_chart(fig_geo)

# Display with Streamlit
