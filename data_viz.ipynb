# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.options.display.float_format = '{:.0f}'.format

# Load dataset
def load_data():
    return pd.read_csv(r'/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv', lineterminator='\n')

# Load data
df_combined = load_data()

# Clean column names (removing '\r')
df_combined.columns = df_combined.columns.str.replace('\r', '')

# Title of the dashboard
st.title("Twitter Election Data Dashboard")

# Drop missing latitude and longitude values
geo_data = df_combined.dropna(subset=['latitude', 'longitude'])

# Visualization: Geographic Heatmap of Tweets
st.header("Geospatial Distribution of Tweets by Candidate")
fig = px.scatter_geo(geo_data, lat='latitude', lon='longitude',
                     hover_name='candidate', color='candidate',
                     title="Tweet Locations by Candidate",
                     labels={'latitude': 'Latitude', 'longitude': 'Longitude'})
st.plotly_chart(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install seaborn

# %%
# !pip install streamlit seaborn matplotlib plotly
# Out:
# Requirement already satisfied: streamlit in /Users/may/anaconda3/lib/python3.11/site-packages (1.39.0)
# Requirement already satisfied: seaborn in /Users/may/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: matplotlib in /Users/may/anaconda3/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: plotly in /Users/may/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=20 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (5.28.2)
# Requirement already satisfied: pyarrow>=7.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (13.9.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/may/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/may/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: jinja2 in /Users/may/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: narwhals>=1.5.2 in /Users/may/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (1.10.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: pytz>=2020.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/may/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/may/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/may/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/may/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/may/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/may/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)

# %%
file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'
df = pd.read_csv(file_path, lineterminator='\n')

df.head()
# Out:
#             created_at             tweet_id  likes  retweet_count  \
# 0  2020-10-15 00:00:02  1316529228091846912      2              1
# 1  2020-10-15 00:00:02  1316529227471237120      0              0
# 2  2020-10-15 00:00:08  1316529252301451264      4              3
# 3  2020-10-15 00:00:17  1316529291052675072      2              0
# 4  2020-10-15 00:00:17  1316529289949569024      0              0
#
#                 source             user_id       user_join_date  \
# 0      twitter web app             8436472  2007-08-26 05:56:11
# 1        trumpytweeter  828355589206056960  2017-02-05 21:32:17
# 2   twitter for iphone            47413798  2009-06-15 19:05:35
# 3  twitter for android          1138416104  2013-02-01 01:37:38
# 4   twitter for iphone  767401841030209536  2016-08-21 16:43:51
#
#    user_followers_count      user_location        city        country  \
# 0                  1185           portland    portland  united states
# 1                    32             unkown      unkown         unkown
# 2                  5393      washington dc  washington  united states
# 3                  2363  perris,california      unkown  united states
# 4                    75         powell, tn      unkown         unkown
#
#                   state candidate  \
# 0                oregon     trump
# 1                unkown     trump
# 2  district of columbia     trump
# 3            california     trump
# 4                unkown     trump
#
#                                                                                                                             tweet_cleaned\r
# 0  #trump student used hear years ten years heard china 2019 15 dont know many asked many said sir dont know millions like 300 million um\r
# 1                                                                            2 hours since last tweet #trump maybe busy tremendously busy\r
# 2                                                                                                      get tie get tie #trump rally #iowa\r
# 3                         clady62 15 minutes long time ago omarosa never represented black community #thereidout cried #trump begging job\r
# 4                                                                                            richardmarx glad u got house dick#trump 2020\r

# %%
import os

file_path = '/Users/may/Documents/GitHub/DataCircle_Twitter_Project/twitter_cleaned_data.csv'

if os.path.exists(file_path):
    print("File exists.")
    # Try reading the CSV file
    import pandas as pd
    df = pd.read_csv(file_path, lineterminator='\n')
    print(df.head())
else:
    print(f"File not found: {file_path}")
# Out:
# File exists.
#             created_at             tweet_id  likes  retweet_count  \
# 0  2020-10-15 00:00:02  1316529228091846912      2              1
# 1  2020-10-15 00:00:02  1316529227471237120      0              0
# 2  2020-10-15 00:00:08  1316529252301451264      4              3
# 3  2020-10-15 00:00:17  1316529291052675072      2              0
# 4  2020-10-15 00:00:17  1316529289949569024      0              0
#
#                 source             user_id       user_join_date  \
# 0      twitter web app             8436472  2007-08-26 05:56:11
# 1        trumpytweeter  828355589206056960  2017-02-05 21:32:17
# 2   twitter for iphone            47413798  2009-06-15 19:05:35
# 3  twitter for android          1138416104  2013-02-01 01:37:38
# 4   twitter for iphone  767401841030209536  2016-08-21 16:43:51
#
#    user_followers_count      user_location        city        country  \
# 0                  1185           portland    portland  united states
# 1                    32             unkown      unkown         unkown
# 2                  5393      washington dc  washington  united states
# 3                  2363  perris,california      unkown  united states
# 4                    75         powell, tn      unkown         unkown
#
#                   state candidate  \
# 0                oregon     trump
# 1                unkown     trump
# 2  district of columbia     trump
# 3            california     trump
# 4                unkown     trump
#
#                                                                                                                             tweet_cleaned\r
# 0  #trump student used hear years ten years heard china 2019 15 dont know many asked many said sir dont know millions like 300 million um\r
# 1                                                                            2 hours since last tweet #trump maybe busy tremendously busy\r
# 2                                                                                                      get tie get tie #trump rally #iowa\r
# 3                         clady62 15 minutes long time ago omarosa never represented black community #thereidout cried #trump begging job\r
# 4                                                                                            richardmarx glad u got house dick#trump 2020\r

# %%
df = pd.read_csv('twitter_cleaned_data.csv')

plt.figure(figsize=(10, 6))

# Plot the distribution of likes using Seaborn
sns.histplot(df['likes'], bins=30, kde=True)

# Add titles and labels
plt.title('Distribution of Likes', fontsize=16)
plt.xlabel('Number of Likes', fontsize=12)
plt.ylabel('Frequency', fontsize=12)


plt.show()
